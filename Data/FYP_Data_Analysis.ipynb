# %%
print("Hello FYP!")
# Out:
# Hello FYP!

# %%
import pandas as pd

print("Pandas version:", pd.__version__)
# Out:
# Pandas version: 3.0.5

# %%
import os

print(os.getcwd())
# Out:
# C:\Users\asad2\sidra_python

# %%
import os

print(os.listdir())
# Out:
# ['.ipynb_checkpoints', 'cleaned_copy_of_employee_attrition.csv', 'Customer_Churn_Analysis', 'employee_attrition_dataset.csv', 'exploratory data analysis', 'FYP', 'FYP_Data_Analysis.ipynb', 'generate_sales.py', 'HR.py', 'new_students.csv', 'project_01.log', 'Project_01_vendors.py', 'requirements.txt', 'sales_database', 'students.csv', 'text', 'Vendor_Analysis.py', 'vendor_Data_Analysis.py', 'venv']

# %%
import os

print(os.listdir("FYP"))
# Out:
# ['Data']

# %%
import os

print(os.listdir("FYP/Data"))
# Out:
# ['synthetic_anthropometric_practice_dataset_800.csv']

# %%
import pandas as pd

df = pd.read_csv("FYP/Data/synthetic_anthropometric_practice_dataset_800.csv")

df.head()
# Out:
#   Participant_ID     Sex  Age_years  Height_cm  Weight_kg    BMI  \
# 0       SYN_0001    Male         31     175.55      76.93  24.96
# 1       SYN_0002  Female         29     162.01      51.22  19.51
# 2       SYN_0003    Male         24     176.26      75.70  24.37
# 3       SYN_0004    Male         29     171.79      72.57  24.59
# 4       SYN_0005  Female         23     160.67      51.11  19.80
#
#           Residence Ethnicity_Ancestry_Group Foot_Dominance Foot_Pathology  \
# 0  Synthetic_Zone_B        Synthetic_Group_3          Right             No
# 1  Synthetic_Zone_D        Synthetic_Group_4          Right             No
# 2  Synthetic_Zone_D        Synthetic_Group_2          Right             No
# 3  Synthetic_Zone_B        Synthetic_Group_2          Right             No
# 4  Synthetic_Zone_E        Synthetic_Group_2          Right             No
#
#    ...  Heel_Breadth_cm  Bimalleolar_Breadth_cm  Ankle_Height_cm  \
# ...

# %%
df.columns
# Out:
# Index(['Participant_ID', 'Sex', 'Age_years', 'Height_cm', 'Weight_kg', 'BMI',
#        'Residence', 'Ethnicity_Ancestry_Group', 'Foot_Dominance',
#        'Foot_Pathology', 'Foot_Length_cm', 'Foot_Breadth_cm',
#        'Instep_Length_cm', 'Heel_Breadth_cm', 'Bimalleolar_Breadth_cm',
#        'Ankle_Height_cm', 'Calf_Height_cm',
#        'Medial_Lateral_Malleolus_Height_cm', 'Calf_Circumference_cm',
#        'Ankle_Circumference_cm', 'Heel_Ankle_Circumference_cm',
#        'Instep_Circumference_cm', 'Ball_of_Foot_Circumference_cm'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 800 entries, 0 to 799
# Data columns (total 23 columns):
#  #   Column                              Non-Null Count  Dtype
# ---  ------                              --------------  -----
#  0   Participant_ID                      800 non-null    str
#  1   Sex                                 800 non-null    str
#  2   Age_years                           800 non-null    int64
#  3   Height_cm                           800 non-null    float64
#  4   Weight_kg                           800 non-null    float64
#  5   BMI                                 800 non-null    float64
#  6   Residence                           800 non-null    str
#  7   Ethnicity_Ancestry_Group            800 non-null    str
#  8   Foot_Dominance                      800 non-null    str
#  9   Foot_Pathology                      800 non-null    str
#  10  Foot_Length_cm                      800 non-null    float64
# ...

# %%
df.describe()
# Out:
#         Age_years   Height_cm   Weight_kg         BMI  Foot_Length_cm  \
# count  800.000000  800.000000  800.000000  800.000000      800.000000
# mean    23.246250  167.146463   63.844812   22.798275       24.792338
# std      3.964247    9.172128   11.588417    3.378484        1.562636
# min     18.000000  145.000000   42.000000   15.980000       20.600000
# 25%     20.000000  160.370000   54.955000   20.542500       23.630000
# 50%     23.000000  167.035000   63.575000   22.725000       24.770000
# 75%     26.000000  173.962500   71.442500   25.082500       26.002500
# max     37.000000  195.000000  105.040000   33.570000       29.490000
#
#        Foot_Breadth_cm  Instep_Length_cm  Heel_Breadth_cm  \
# count       800.000000        800.000000       800.000000
# mean          6.897700         16.838262         2.170187
# std           0.440309          1.114569         0.207622
# min           5.500000         13.850000         1.400000
# ...

# %%
df["Sex"].value_counts()
# Out:
# Sex
# Female    405
# Male      395
# Name: count, dtype: int64

# %%
import matplotlib.pyplot as plt

plt.hist(df["Height_cm"], bins=20)
plt.xlabel("Height (cm)")
plt.ylabel("Number of Participants")
plt.title("Distribution of Height")
plt.show()

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

stats.probplot(df["Height_cm"], dist="norm", plot=plt)
plt.title("Q-Q Plot of Height")
plt.show()

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

male_height = df[df["Sex"] == "Male"]["Height_cm"]
female_height = df[df["Sex"] == "Female"]["Height_cm"]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

stats.probplot(male_height, dist="norm", plot=axes[0])
axes[0].set_title("Q-Q Plot - Male Height")

stats.probplot(female_height, dist="norm", plot=axes[1])
axes[1].set_title("Q-Q Plot - Female Height")

plt.tight_layout()
plt.show()

# %%
df.groupby("Sex")["Height_cm"].agg(["count", "mean", "std"])
# Out:
#         count        mean       std
# Sex
# Female    405  160.768321  6.268473
# Male      395  173.686076  6.754408

# %%
from scipy.stats import ttest_ind

male_height = df[df["Sex"] == "Male"]["Height_cm"]
female_height = df[df["Sex"] == "Female"]["Height_cm"]

t_stat, p_value = ttest_ind(male_height, female_height)

print("t-statistic:", t_stat)
print("p-value:", p_value)
# Out:
# t-statistic: 28.04734547656835
# p-value: 5.34172623992791e-121

# %%
from scipy.stats import levene

levene_stat, levene_p = levene(male_height, female_height)

print("Levene statistic:", levene_stat)
print("Levene p-value:", levene_p)
# Out:
# Levene statistic: 0.3708655279503309
# Levene p-value: 0.5427061810258008

# %%
import numpy as np

n_male = len(male_height)
n_female = len(female_height)

pooled_sd = np.sqrt(
    ((n_male - 1) * male_height.var(ddof=1) +
     (n_female - 1) * female_height.var(ddof=1))
    / (n_male + n_female - 2)
)

cohens_d = (male_height.mean() - female_height.mean()) / pooled_sd

print("Cohen's d:", cohens_d)
# Out:
# Cohen's d: 1.9834017773935255

# %%
# Mean height was 160.77 ± 6.27 cm among females and 173.69 ± 6.75 cm among males. 
# An independent-samples t-test showed a statistically significant difference in height between the groups, 
# t = 28.05, p < 0.001. Levene's test indicated no significant difference in variances (p = 0.543), and 
# Cohen's d = 1.98 indicated a very large effect size.

# %%
df.groupby("Sex")["Foot_Length_cm"].agg(["count", "mean", "std"])
# Out:
#         count       mean       std
# Sex
# Female    405  23.733852  1.115488
# Male      395  25.877620  1.159070

# %%
import scipy.stats as stats
import matplotlib.pyplot as plt

male_foot = df[df["Sex"] == "Male"]["Foot_Length_cm"]
female_foot = df[df["Sex"] == "Female"]["Foot_Length_cm"]

fig, axes = plt.subplots(1, 2, figsize=(12, 5))

stats.probplot(male_foot, dist="norm", plot=axes[0])
axes[0].set_title("Q-Q Plot - Male Foot Length")

stats.probplot(female_foot, dist="norm", plot=axes[1])
axes[1].set_title("Q-Q Plot - Female Foot Length")

plt.tight_layout()
plt.show()

# %%
from scipy.stats import levene

levene_stat, levene_p = levene(male_foot, female_foot)

print("Levene statistic:", levene_stat)
print("Levene p-value:", levene_p)
# Out:
# Levene statistic: 0.6309513935946338
# Levene p-value: 0.4272427038218016
